# %%
import geopandas as gpd

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
gdf = gpd.read_file(r"C:\dev\05_geodata\landuse\rmk_poi\rmk.geojson")
gdf.head(5)
# Out:
#    coord_x  coord_y                                          equipment  \
# 0   390060  6483103  Rada algab Kalasma telkimisalalt, on tähistatu...
# 1   389927  6480555  Kattega lõkkekoht, katusega pinklaud, kuivkäim...
# 2   591831  6572957  soodusprogrammid üldhariduskoolidele ja lastea...
# 3   698736  6556476  Infostend, 4 pinki, lõkkekoht, kuivkäimla, puu...
# 4   679596  6459798  Kaetud lõkkease, laud ja pingid, lõkkepuude va...
#
#    has_firesite  has_tenting  \
# 0           1.0          1.0
# 1           1.0          1.0
# 2           NaN         -1.0
# 3           NaN          1.0
# 4           1.0          1.0
#
#                                                 href  \
# 0  http://loodusegakoos.ee/kuhuminna/puhkealad/sa...
# 1  http://loodusegakoos.ee/kuhuminna/puhkealad/sa...
# 2  http://loodusegakoos.ee/kuhuminna/puhkealad/ae...
# 3  http://loodusegakoos.ee/kuhuminna/puhkealad/pe...
# 4  http://loodusegakoos.ee/kuhuminna/puhkealad/ki...
#
#                                             location  \
# 0  Mustjala vallas Kalasma ja Abula külas, puhkea...
# 1  Mustjala vallas Kalasma ja Abula külas. Puhkea...
# 2  Jaama 7, Aegviidu, 74501 HarjumaaObjekt nr 1 p...
# 3                             Imatu küla Iisaku vald
# 4                                Ahja vald, Põlvamaa
#
#                        name  \
# 0  Abula matkarada (6,8 km)
# 1         Abula telkimisala
# 2   Aegviidu külastuskeskus
# 3         Agusalu lõkkekoht
# 4            Ahja lõkkekoht
#
#                                               sights            type  \
# 0  Kevadel lubjalembeste taimede massiline õitsen...       matkarada
# 1  Ilus kliburannik, kaunis vaade Tagalahele. Läh...     telkimisala
# 2  Külastuskeskus asub Kõrvemaa südames. Ürgsed s...  külastuskeskus
# 3                          Imatu järv, Ristikivi soo       lõkkekoht
# 4                                               None       lõkkekoht
#
#                     geometry
# 0  POINT (22.11547 58.47428)
# 1  POINT (22.11441 58.45138)
# 2  POINT (25.61125 59.28492)
# 3  POINT (27.46959 59.10072)
# 4  POINT (27.05901 58.24213)

# %%
display(gdf.crs)
# Out:
# {'init': 'epsg:4326'}

# %%
est = gpd.read_file(r"C:\dev\05_geodata\dem\countries\estonia_without_lakes.shp")
display(est.crs)
est
# Out:
# {'init': 'epsg:4326'}
#    FID_estoni  OBJECTID     NAME ISO3 ISO2 FIPS  COUNTRY  ENGLISH   FRENCH  \
# 0           0        76  Estonia  EST   EE   EN  Estonia  Estonia  Estonie
#
#    SPANISH  ... kkr_kood nimetus knr_id markused vajalik vajalik_t  \
# 0  Estonia  ...     None    None    0.0     None       0      None
#
#         _count          _sum      _mean  \
# 0  131241100.0  7.718100e+09  58.808563
#
#                                             geometry
# 0  MULTIPOLYGON Z (((25.82342 59.67719 0.00000, 2...
#
# [1 rows x 41 columns]

# %%
est3301 = est.to_crs(epsg=3301)
base = est3301.plot(facecolor="none", edgecolor='blue', lw=0.7, alpha=0.8)

# %%
x = """Õpperada
Matkarada
Rattarada
Maastikusõidurada
Telkimisala
Lõkkekoht
Kattega lõkkekoht
Metsaonn
Metsamaja
Looduskeskus
Külastuskeskus
Teabepunkt
Vaatetorn
Puhkekoht
Matkavõimalus
Prügi sorteerimise võimalus
Telkimisvõimalus
Invavõimalus
Talvine kasutus
Muu"""


y = """Study trail
Hiking trail
Cycling trail
Off-road trail
Campsite
Campfire site
Outdoor fireplace
Forest hut
Rental hut
Nature House
Visitor Centre
Information point
Observation Tower
Rest Stop
Hiking options
Recycling point
Camping facilities
Wheelchair accessibility
Winter accessibility
Other"""

# %%
x1 = x.split('\n')
x1
# Out:
# ['Õpperada',
#  'Matkarada',
#  'Rattarada',
#  'Maastikusõidurada',
#  'Telkimisala',
#  'Lõkkekoht',
#  'Kattega lõkkekoht',
#  'Metsaonn',
#  'Metsamaja',
#  'Looduskeskus',
#  'Külastuskeskus',
#  'Teabepunkt',
#  'Vaatetorn',
#  'Puhkekoht',
#  'Matkavõimalus',
#  'Prügi sorteerimise võimalus',
#  'Telkimisvõimalus',
#  'Invavõimalus',
#  'Talvine kasutus',
#  'Muu']

# %%
y1 = y.split('\n')

# %%
b = [(a[0],a[1]) for a in zip(x1,y1)]

# %%
b
# Out:
# [('Õpperada', 'Study trail'),
#  ('Matkarada', 'Hiking trail'),
#  ('Rattarada', 'Cycling trail'),
#  ('Maastikusõidurada', 'Off-road trail'),
#  ('Telkimisala', 'Campsite'),
#  ('Lõkkekoht', 'Campfire site'),
#  ('Kattega lõkkekoht', 'Outdoor fireplace'),
#  ('Metsaonn', 'Forest hut'),
#  ('Metsamaja', 'Rental hut'),
#  ('Looduskeskus', 'Nature House'),
#  ('Külastuskeskus', 'Visitor Centre'),
#  ('Teabepunkt', 'Information point'),
#  ('Vaatetorn', 'Observation Tower'),
#  ('Puhkekoht', 'Rest Stop'),
#  ('Matkavõimalus', 'Hiking options'),
#  ('Prügi sorteerimise võimalus', 'Recycling point'),
#  ('Telkimisvõimalus', 'Camping facilities'),
#  ('Invavõimalus', 'Wheelchair accessibility'),
#  ('Talvine kasutus', 'Winter accessibility'),
#  ('Muu', 'Other')]

# %%
def transla(ee):
    for tup in b:
        if tup[0].lower() == ee.lower():
            return tup[1].lower()
        
gdf['type_eng'] = gdf['type'].apply(transla)

# %%
gdf
# Out:
#      coord_x  coord_y                                          equipment  \
# 0     390060  6483103  Rada algab Kalasma telkimisalalt, on tähistatu...
# 1     389927  6480555  Kattega lõkkekoht, katusega pinklaud, kuivkäim...
# 2     591831  6572957  soodusprogrammid üldhariduskoolidele ja lastea...
# 3     698736  6556476  Infostend, 4 pinki, lõkkekoht, kuivkäimla, puu...
# 4     679596  6459798  Kaetud lõkkease, laud ja pingid, lõkkepuude va...
# ..       ...      ...                                                ...
# 608   590957  6452269  Rada on täies ulatused kaetud hakkpuiduga, mit...
# 609   505877  6537439                               Kuivkäimla, metsaonn
# 610   674720  6402301  Ööbikuorus on trepid, käsipuud, purded, istepi...
# 611   569986  6471724  metsaonn, lõkkekoht grillrestiga, puude varjua...
# 612   569995  6471717                                               None
#
#      has_firesite  has_tenting  \
# 0             1.0          1.0
# 1             1.0          1.0
# 2             NaN         -1.0
# 3             NaN          1.0
# 4             1.0          1.0
# ..            ...          ...
# 608           NaN          NaN
# 609           NaN          NaN
# 610           NaN          NaN
# 611           NaN          1.0
# 612           NaN          1.0
#
#                                                   href  \
# 0    http://loodusegakoos.ee/kuhuminna/puhkealad/sa...
# 1    http://loodusegakoos.ee/kuhuminna/puhkealad/sa...
# 2    http://loodusegakoos.ee/kuhuminna/puhkealad/ae...
# 3    http://loodusegakoos.ee/kuhuminna/puhkealad/pe...
# 4    http://loodusegakoos.ee/kuhuminna/puhkealad/ki...
# ..                                                 ...
# 608  http://loodusegakoos.ee/kuhuminna/puhkealad/sa...
# 609  http://loodusegakoos.ee/kuhuminna/puhkealad/no...
# 610  http://loodusegakoos.ee/kuhuminna/kaitsealad/h...
# 611  http://loodusegakoos.ee/kuhuminna/rahvuspargid...
# 612  http://loodusegakoos.ee/kuhuminna/rahvuspargid...
#
#                                               location  \
# 0    Mustjala vallas Kalasma ja Abula külas, puhkea...
# 1    Mustjala vallas Kalasma ja Abula külas. Puhkea...
# 2    Jaama 7, Aegviidu, 74501 HarjumaaObjekt nr 1 p...
# 3                               Imatu küla Iisaku vald
# 4                                  Ahja vald, Põlvamaa
# ..                                                 ...
# 608  Raja algus asub Viljandi maakonnas Õisu alevikus.
# 609                         Märjamaa vallas, Raplamaal
# 610                               Rõuge vald, Võrumaa.
# 611  Iia külas, Kõpu vallas, Viljandimaal. Regio al...
# 612  Iia külas, Kõpu vallas, Viljandimaal. Regio at...
#
#                                   name  \
# 0             Abula matkarada (6,8 km)
# 1                    Abula telkimisala
# 2              Aegviidu külastuskeskus
# 3                    Agusalu lõkkekoht
# 4                       Ahja lõkkekoht
# ..                                 ...
# 608            Õisu matkarada (2,5 km)
# 609                 Õmma raba metsaonn
# 610  Ööbikuoru väike matkarada (450 m)
# 611                     Öördi metsaonn
# 612            Öördi õpperada (2,4 km)
#
#                                                 sights            type  \
# 0    Kevadel lubjalembeste taimede massiline õitsen...       matkarada
# 1    Ilus kliburannik, kaunis vaade Tagalahele. Läh...     telkimisala
# 2    Külastuskeskus asub Kõrvemaa südames. Ürgsed s...  külastuskeskus
# 3                            Imatu järv, Ristikivi soo       lõkkekoht
# 4                                                 None       lõkkekoht
# ..                                                 ...             ...
# 608               Kõpu jõe ürgorg ja liivakivi paljand       matkarada
# 609                  Lao järv ja omapärane rabamaastik        metsaonn
# 610  Ööbikuorg, Linnamägi, Ööbikuoru hüdrotöökoda-m...       matkarada
# 611                       Öördi raba, Öördi jäänukjärv        metsaonn
# 612                       Öördi raba, Öördi jäänukjärv        õpperada
#
#                       geometry        type_eng
# 0    POINT (22.11547 58.47428)    hiking trail
# 1    POINT (22.11441 58.45138)        campsite
# 2    POINT (25.61125 59.28492)  visitor centre
# 3    POINT (27.46959 59.10072)   campfire site
# 4    POINT (27.05901 58.24213)   campfire site
# ..                         ...             ...
# 608  POINT (25.54710 58.20189)    hiking trail
# 609  POINT (24.10220 58.97594)      forest hut
# 610  POINT (26.93328 57.72837)    hiking trail
# 611  POINT (25.19639 58.38038)      forest hut
# 612  POINT (25.19653 58.38032)     study trail
#
# [613 rows x 12 columns]

# %%
gdf.loc[gdf['type_eng'].isna()]
# Out:
# Empty GeoDataFrame
# Columns: [coord_x, coord_y, equipment, has_firesite, has_tenting, href, location, name, sights, type, geometry, type_eng]
# Index: []

# %%
gdf['type'].unique()
# Out:
# array(['matkarada', 'telkimisala', 'külastuskeskus', 'lõkkekoht',
#        'õpperada', 'vaatetorn', 'puhkekoht', 'rattarada', 'muu',
#        'metsamaja', 'metsaonn', 'looduskeskus', 'maastikusõidurada',
#        'teabepunkt'], dtype=object)

# %%
gdf['type_eng'].unique()
# Out:
# array(['hiking trail', 'campsite', 'visitor centre', 'campfire site',
#        'study trail', 'observation tower', 'rest stop', 'cycling trail',
#        'other', 'rental hut', 'forest hut', 'nature house',
#        'off-road trail', 'information point'], dtype=object)

# %%
poi3301 = gdf.to_crs(epsg=3301)

# %%
fig, ax = plt.subplots(figsize=(20,15))

plt.title('Estonian State Forest Management Centre (RMK) public recreations sites',fontsize=15)


est3301.plot(facecolor='black', edgecolor='black', lw=0.7, alpha=0.8, ax=ax)
poi3301.plot(column='type_eng', ax=ax, categorical=True, legend=True, markersize=9, cmap='tab20')

# Adjust legend location
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.0,0.66))

ax.set_axis_off()

plt.show()
fig.savefig('../source/_static/day-01-points.png')
