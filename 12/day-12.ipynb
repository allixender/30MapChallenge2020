# %% [markdown]
# ## Day 12 - Map not made with GIS

# %% [markdown]
# ### Data
#
# My image from day 04

# %%
nice_img = '../04/day-04-hexa.png'

# %%
import matplotlib.pyplot as plt
from PIL import Image as PilImage

# %%
fp = open(nice_img,'rb')
image_file = PilImage.open(fp)

# %%
plt.imshow(image_file)

# %%
import ascii_art

# %%
ascii_art.convert_image(nice_img, 0.15, 0.3)
# Out:
# Size info: 185   92
#
#
#
#
#
#
#
#
#                                                                                 ,;Ii><<<~+___+++~<<>>iI:,
#                                                                        ,Ii~+-]]][[[[[[]]]-_-~<+~<+<<_[111[[]?_~iI,
#                                                                  ,;!i>iI!ii!><<>>i<+<~<<i!<~+~~~iiI!i>_]]]]][[[111[]-<!:
#                                                             ,;!!I;:,  ;!i><~+++__---_-?-___-++_++<<_-+~<+_]?-?-?]]]][111[-+i,
#                                                          ;!!I,  , ;!>>i<++?-???]][-_-??????-?<+_]-]]]]?-<,+++?-_--_--?]]][[11]+!,
#                                                      :!!I:  ,;!i><+_?__??]++--?_---]]]]]]]]]]]]]]]]]]]]]]-?+_?][?]?-?++-~+<+-?]11]+I
#                                                   ;!!;   :;I>~+--?]]][[1]?]1-_-_~[-?]]]]]]]]]]]]]]]]]]]]]]]]???]1][[?[??_+~~+<i>?][1[_I
# ...

# %%
fig, ax = plt.subplots(figsize=(21,17))

plt.imshow(PilImage.open(open('../source/_static/day-12-ascii-globe.png', 'rb')))
