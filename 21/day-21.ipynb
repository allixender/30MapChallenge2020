# %% [markdown]
# ## Day 21 Water
#
# ### Data
#
# The establishment of the meteorological observatory of the University of Tartu laid the foundation for the hydrological observation network of Estonian inland waters. The observatory first measured the water level of the Emajõgi River in 1866, but more regular measurements began in the spring of 1867. Daily water level and regular flow measurements began on the Emajõgi River in 1922. In the 1920s, regular flow measurements were started on many other Estonian rivers.
#
# From here it is possible to download the daily flow rates or drainage of the operating hydrometry stations. Information about operating stations can be found by clicking on the following link: https://www.ilmateenistus.ee/ilmateenistus/ Vaatlusvork/#hydro
#
# The name of the station is followed by a homogeneous reference period, in this exercise we limit the periods of observation to the last 20 years in order to make the trends comparable.
#
# - https://www.ilmateenistus.ee/siseveed/ajaloolised-vaatlusandmed/vooluhulgad/

# %%
import urllib.request

import pandas as pd
import numpy as np

import pymannkendall as mk

# %%
import urllib.request

opener = urllib.request.build_opener()
opener.addheaders = [('User-agent', 'TartuMapchallenger/100.0')]
urllib.request.install_opener(opener)

# %%
local_file, headers = urllib.request.urlretrieve("https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Reola-1986-2019.csv")

# %%
df = pd.read_csv(local_file, sep=';')

df['date2'] = df['Date'].apply(pd.to_datetime)

df['flow'] = df['Q [m3/s]'].apply(lambda x: x.replace('.', '').replace(',', '.')).apply(pd.to_numeric, errors='coerce')
df.head(5)
# Out:
#          Date Q [m3/s]      date2  flow
# 0  01.01.1986     1,25 1986-01-01  1.25
# 1  02.01.1986     1,16 1986-02-01  1.16
# 2  03.01.1986     1,12 1986-03-01  1.12
# 3  04.01.1986     1,11 1986-04-01  1.11
# 4  05.01.1986     1,03 1986-05-01  1.03

# %%
df.dtypes
# Out:
# Date                object
# Q [m3/s]            object
# date2       datetime64[ns]
# flow               float64
# dtype: object

# %% [markdown]
# ### Testing Mann-Kendall python package to calculate trend for flow timeseries
#
# - https://www.researchgate.net/publication/334688255_pyMannKendall_a_python_package_for_non_parametric_Mann_Kendall_family_of_trend_tests
# - https://pypi.org/project/pymannkendall/

# %%
result = mk.original_test(df['flow'].values)

print(result)
# Out:
# Mann_Kendall_Test(trend='decreasing', h=True, p=0.00582837501885014, z=-2.7572837517882007, Tau=-0.016497018249524435, s=-1272078.0, var_s=212845208288.0, slope=-5.4878718033146735e-06, intercept=1.2640741960267807)

# %% [markdown]
# ### trying to get all the river station historical timeseries
#
# https://www.dataquest.io/blog/web-scraping-tutorial-python/

# %%
import requests
page = requests.get("https://www.ilmateenistus.ee/siseveed/ajaloolised-vaatlusandmed/vooluhulgad/")
page
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(page.content, 'html.parser')

# %%
"/html/body/section/div/div/article/section/table"
# Out:
# '/html/body/section/div/div/article/section/table'

# %%
t = soup.select('.table-override > tbody > tr > td > a')

# %%
len(t)
# Out:
# 64

# %%
t
# Out:
# [<a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Aesoo-1929-2019.csv">1929-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Ahja-1960-2019.csv">1960-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Alajoe-1978-2019.csv">1978-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Arbavere-2007-2019.csv">2007-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Audru-2007-2019.csv">1986-1997,</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Audru-2007-2019.csv">2007-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Elva-1981-1996_2009-2019.csv">1981-1996,</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Elva-1981-1996_2009-2019.csv">2009-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Huuru_1968-2019.csv">1968-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Kaansoo_1980-1966_2007-2019.csv">1980-1996,</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Kaansoo_1980-1966_2007-2019.csv">2007-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Kasari_1925-2019.csv">1925-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Kehra_1982-2019.csv">1982-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Keila_1923-2019.csv">1923-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Kirumpaa-2015-2019.csv">2015-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Kloostrimetsa-1973-1999_2007-2019.csv">1973-1999,</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Kloostrimetsa-1973-1999_2007-2019.csv">2007-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Konuvere-1947-1999_2007-2019.csv">1947-1999,</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Konuvere-1947-1999_2007-2019.csv">2007-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Korela-1962-1966_2007-2019.csv">1962-1966,</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Korela-1962-1966_2007-2019.csv">2007-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Kaapa-1955-2019.csv">1955-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Laadi-2007-2019.csv">2007-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Luguse-1970-2019.csv">1970-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Luganuse-1923-2019.csv">1923-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Narvakarjaar-2006-2019.csv">2006-2019</a>,
#  <a href="http://www.ilmateenistus.ee/wp-content/uploads/2020/09/Narvalinn_2003-2019.csv">2003-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Nurme-2007-2019.csv">2007-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Oore-1922-2019.csv">1922-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Pajupea-1928-2019.csv">1928-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Pajusi-1932-2019.csv">1932-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Pudisoo-1961-2019.csv">1961-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/PohjakaI-1970-2019.csv">1970-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/PohjakaII-1976-2019.csv">1976-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Rannu-Joesuu-1961-2019.csv">1961-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Reola-1986-2019.csv">1986-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Riisa-1925-2019.csv">1925-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Roostoja-1974-2019.csv">1974-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Rapina-1959-2019.csv">1959-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Separa-2011-2019.csv">2011-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Sami-1942-2019.csv">1942-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Taheva-2007-2019.csv">2007-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Tahkuse-1932-2019.csv">1932-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Tartu-1922-2019.csv">1922-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Tarvastu-2007-2019.csv">2007-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Toila-Oru-2008-2019.csv">2008-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Tori-1956-2019.csv">1956-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Tudulinna-1956-2019.csv">1956-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Tolliste-1922-2019.csv">1922-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Torva-1946-2019.csv">1946-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Torve-1925-2019.csv">1925-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Tanassilma-1955-1969_2009-2019.csv">1955-1969,</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Tanassilma-1955-1969_2009-2019.csv">2009-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Turi-Alliku-1971-1972_1977-2019.csv">1971-1972,</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Turi-Alliku-1971-1972_1977-2019.csv">1977-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Uue-Love-1934-2019.csv">1934-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Vanakula-1946-2019.csv">1946-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Varangu-2011-2019.csv">2011-2019</a>,
#  <a href="http://www.ilmateenistus.ee/wp-content/uploads/2020/09/Narvalinn_2003-2019.csv">1903-1914,</a>,
#  <a href="http://www.ilmateenistus.ee/wp-content/uploads/2020/09/Narvalinn_2003-2019.csv">1921-1943,</a>,
#  <a href="http://www.ilmateenistus.ee/wp-content/uploads/2020/09/Narvalinn_2003-2019.csv">1945-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Vihterpalu-1930-1944_1946-2019.csv">1930-1944,</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Vihterpalu-1930-1944_1946-2019.csv">1946-2019</a>,
#  <a href="https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Vodja_1964-2019.csv">1964-2019</a>]

# %%
from time import sleep
from shutil import copyfile
from urllib.parse import urlparse

# %%
def pre_process(url):
    print(url)
    local_file, headers = urllib.request.urlretrieve(url)
    
    o = urlparse(url)
    filename = o.path.split('/')[-1]
    copyfile(local_file, filename)
    
    df = pd.read_csv(local_file, sep=';')
        
    df['date2'] = df['Date'].apply(pd.to_datetime)
    df['flow'] = df['Q [m3/s]'].apply(lambda x: x.replace('.', '').replace(',', '.')).apply(pd.to_numeric, errors='coerce')
    try:
        df2 = df.set_index('date2', verify_integrity=True)
    except ValueError as ex:
        print(f"{filename} date2 index verification failed")
        pass
    
    parqfile = filename.replace('.csv', '.parquet.gzip')
    df.to_parquet(parqfile, index=True, compression='gzip') 
    
    collector.append({'url': url,
                      'parquet': parqfile,
                     'csv': filename})
    
    print(filename)

# %%
collector = []

for i in t:
    pre_process(i)
    sleep(30)

# %%
import toolz

# %%
from toolz.curried import pipe, map, filter, get, count

# %%
with open('target_urls.txt', 'w', encoding='utf8') as fh:
    for i in t:
        url = i['href']
        fh.write(f"{url}\n")

# %%
pd.DataFrame(collector).to_csv('collected_so_far.csv', encoding='utf8', index=False)

# %%
collector_df = pd.read_csv('collected_so_far.csv', encoding='utf8')

collector = []

for idx, row in collector_df.iterrows():
    collector.append({'url':row['url'],
                      'parquet': row['parquet'],
                     'csv': row['csv']})

# %%
with open('target_urls.txt', 'r', encoding='utf8') as fh:
    lines = fh.readlines()
    
    for line in lines:
        # url = i['href']
        url = line.strip()
        skip = filter( lambda x: x == url , map( get('url'), collector))
        if count(skip) == 0:
            pre_process(url)
            sleep(30)
        else:
            print("skip")
# Out:
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# skip
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Reola-1986-2019.csv
# Reola-1986-2019.csv date2 index verification failed
# Reola-1986-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Riisa-1925-2019.csv
# Riisa-1925-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Roostoja-1974-2019.csv
# Roostoja-1974-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Rapina-1959-2019.csv
# Rapina-1959-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Separa-2011-2019.csv
# Separa-2011-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Sami-1942-2019.csv
# Sami-1942-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Taheva-2007-2019.csv
# Taheva-2007-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Tahkuse-1932-2019.csv
# Tahkuse-1932-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Tartu-1922-2019.csv
# Tartu-1922-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Tarvastu-2007-2019.csv
# Tarvastu-2007-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Toila-Oru-2008-2019.csv
# Toila-Oru-2008-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Tori-1956-2019.csv
# Tori-1956-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Tudulinna-1956-2019.csv
# Tudulinna-1956-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Tolliste-1922-2019.csv
# Tolliste-1922-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Torva-1946-2019.csv
# Torva-1946-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Torve-1925-2019.csv
# Torve-1925-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Tanassilma-1955-1969_2009-2019.csv
# Tanassilma-1955-1969_2009-2019.csv
# skip
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Turi-Alliku-1971-1972_1977-2019.csv
# Turi-Alliku-1971-1972_1977-2019.csv
# skip
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Uue-Love-1934-2019.csv
# Uue-Love-1934-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Vanakula-1946-2019.csv
# Vanakula-1946-2019.csv
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Varangu-2011-2019.csv
# Varangu-2011-2019.csv
# skip
# skip
# skip
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Vihterpalu-1930-1944_1946-2019.csv
# Vihterpalu-1930-1944_1946-2019.csv
# skip
# https://www.ilmateenistus.ee/wp-content/uploads/2020/09/Vodja_1964-2019.csv
# Vodja_1964-2019.csv

# %%
collector_df.head()
# Out:
#                                                  url  \
# 0  https://www.ilmateenistus.ee/wp-content/upload...
# 1  https://www.ilmateenistus.ee/wp-content/upload...
# 2  https://www.ilmateenistus.ee/wp-content/upload...
# 3  https://www.ilmateenistus.ee/wp-content/upload...
# 4  https://www.ilmateenistus.ee/wp-content/upload...
#
#                            parquet                     csv
# 0     Aesoo-1929-2019.parquet.gzip     Aesoo-1929-2019.csv
# 1      Ahja-1960-2019.parquet.gzip      Ahja-1960-2019.csv
# 2    Alajoe-1978-2019.parquet.gzip    Alajoe-1978-2019.csv
# 3  Arbavere-2007-2019.parquet.gzip  Arbavere-2007-2019.csv
# 4     Audru-2007-2019.parquet.gzip     Audru-2007-2019.csv

# %%
len(collector_df)
# Out:
# 58

# %%
# Mann_Kendall_Test(trend='decreasing', h=True, p=0.00582837501885014, z=-2.7572837517882007, Tau=-0.016497018249524435, s=-1272078.0, var_s=212845208288.0, slope=-5.4878718033146735e-06, intercept=1.2640741960267807)

collector_df['trend'] = 'undefined'
collector_df['p'] = np.nan
collector_df['h'] = False
collector_df['slope'] = np.nan
collector_df['years'] = 0

# %%
for idx, row in collector_df.iterrows():
    test_df = pd.read_parquet(row['parquet'])
    
    test_df = test_df.loc[test_df['date2'] >= '1999-04']
    mind = test_df['date2'].min()
    maxd = test_df['date2'].max()
    years = int((maxd - mind).days / 365) 
    # test_df.dtypes
    print(f"{idx} {row['csv']} mind {mind} maxd {maxd} years {years}")
    
    result = mk.original_test(test_df['flow'].values)
    
    collector_df.loc[idx, 'years'] = years
    collector_df.loc[idx, 'trend'] = result.trend
    collector_df.loc[idx, 'p'] = result.p
    collector_df.loc[idx, 'h'] = result.h
    collector_df.loc[idx, 'slope'] = result.slope
    
    # break
    del result
    del test_df
# Out:
# 0 Aesoo-1929-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 1 Ahja-1960-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 2 Alajoe-1978-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 3 Arbavere-2007-2019.csv mind 2007-01-01 00:00:00 maxd 2019-12-31 00:00:00 years 13
# 4 Audru-2007-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 5 Audru-2007-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 6 Elva-1981-1996_2009-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 7 Elva-1981-1996_2009-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 8 Huuru_1968-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 9 Kaansoo_1980-1966_2007-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 10 Kaansoo_1980-1966_2007-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 11 Kasari_1925-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 12 Kehra_1982-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 13 Keila_1923-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 14 Kirumpaa-2015-2019.csv mind 2015-01-01 00:00:00 maxd 2019-12-31 00:00:00 years 5
# 15 Kloostrimetsa-1973-1999_2007-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 16 Kloostrimetsa-1973-1999_2007-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 17 Konuvere-1947-1999_2007-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 18 Konuvere-1947-1999_2007-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 19 Korela-1962-1966_2007-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 20 Korela-1962-1966_2007-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 21 Kaapa-1955-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 22 Laadi-2007-2019.csv mind 2007-01-01 00:00:00 maxd 2019-12-31 00:00:00 years 13
# 23 Luguse-1970-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 24 Luganuse-1923-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 25 Narvakarjaar-2006-2019.csv mind 2006-01-01 00:00:00 maxd 2019-12-31 00:00:00 years 14
# 26 Narvalinn_2003-2019.csv mind 2003-01-01 00:00:00 maxd 2019-12-31 00:00:00 years 17
# 27 Nurme-2007-2019.csv mind 2007-01-01 00:00:00 maxd 2019-12-31 00:00:00 years 13
# 28 Oore-1922-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 29 Pajupea-1928-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 30 Pajusi-1932-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 31 Pudisoo-1961-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 32 PohjakaI-1970-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 33 PohjakaII-1976-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 34 Rannu-Joesuu-1961-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 35 Reola-1986-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 36 Riisa-1925-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 37 Roostoja-1974-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 38 Rapina-1959-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 39 Separa-2011-2019.csv mind 2011-01-01 00:00:00 maxd 2019-12-31 00:00:00 years 9
# 40 Sami-1942-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 41 Taheva-2007-2019.csv mind 2007-01-01 00:00:00 maxd 2019-12-31 00:00:00 years 13
# 42 Tahkuse-1932-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 43 Tartu-1922-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 44 Tarvastu-2007-2019.csv mind 2007-01-01 00:00:00 maxd 2019-12-31 00:00:00 years 13
# 45 Toila-Oru-2008-2019.csv mind 2008-01-01 00:00:00 maxd 2019-12-31 00:00:00 years 12
# 46 Tori-1956-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 47 Tudulinna-1956-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 48 Tolliste-1922-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 49 Torva-1946-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 50 Torve-1925-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 51 Tanassilma-1955-1969_2009-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 52 Turi-Alliku-1971-1972_1977-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 53 Uue-Love-1934-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 54 Vanakula-1946-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 55 Varangu-2011-2019.csv mind 2011-01-01 00:00:00 maxd 2019-12-31 00:00:00 years 9
# 56 Vihterpalu-1930-1944_1946-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20
# 57 Vodja_1964-2019.csv mind 1999-04-01 00:00:00 maxd 2019-12-31 00:00:00 years 20

# %%
collector_df
# Out:
#                                                   url  \
# 0   https://www.ilmateenistus.ee/wp-content/upload...
# 1   https://www.ilmateenistus.ee/wp-content/upload...
# 2   https://www.ilmateenistus.ee/wp-content/upload...
# 3   https://www.ilmateenistus.ee/wp-content/upload...
# 4   https://www.ilmateenistus.ee/wp-content/upload...
# 5   https://www.ilmateenistus.ee/wp-content/upload...
# 6   https://www.ilmateenistus.ee/wp-content/upload...
# 7   https://www.ilmateenistus.ee/wp-content/upload...
# 8   https://www.ilmateenistus.ee/wp-content/upload...
# 9   https://www.ilmateenistus.ee/wp-content/upload...
# 10  https://www.ilmateenistus.ee/wp-content/upload...
# 11  https://www.ilmateenistus.ee/wp-content/upload...
# 12  https://www.ilmateenistus.ee/wp-content/upload...
# 13  https://www.ilmateenistus.ee/wp-content/upload...
# 14  https://www.ilmateenistus.ee/wp-content/upload...
# 15  https://www.ilmateenistus.ee/wp-content/upload...
# 16  https://www.ilmateenistus.ee/wp-content/upload...
# 17  https://www.ilmateenistus.ee/wp-content/upload...
# 18  https://www.ilmateenistus.ee/wp-content/upload...
# 19  https://www.ilmateenistus.ee/wp-content/upload...
# 20  https://www.ilmateenistus.ee/wp-content/upload...
# 21  https://www.ilmateenistus.ee/wp-content/upload...
# 22  https://www.ilmateenistus.ee/wp-content/upload...
# 23  https://www.ilmateenistus.ee/wp-content/upload...
# 24  https://www.ilmateenistus.ee/wp-content/upload...
# 25  https://www.ilmateenistus.ee/wp-content/upload...
# 26  http://www.ilmateenistus.ee/wp-content/uploads...
# 27  https://www.ilmateenistus.ee/wp-content/upload...
# 28  https://www.ilmateenistus.ee/wp-content/upload...
# 29  https://www.ilmateenistus.ee/wp-content/upload...
# 30  https://www.ilmateenistus.ee/wp-content/upload...
# 31  https://www.ilmateenistus.ee/wp-content/upload...
# 32  https://www.ilmateenistus.ee/wp-content/upload...
# 33  https://www.ilmateenistus.ee/wp-content/upload...
# 34  https://www.ilmateenistus.ee/wp-content/upload...
# 35  https://www.ilmateenistus.ee/wp-content/upload...
# 36  https://www.ilmateenistus.ee/wp-content/upload...
# 37  https://www.ilmateenistus.ee/wp-content/upload...
# 38  https://www.ilmateenistus.ee/wp-content/upload...
# 39  https://www.ilmateenistus.ee/wp-content/upload...
# 40  https://www.ilmateenistus.ee/wp-content/upload...
# 41  https://www.ilmateenistus.ee/wp-content/upload...
# 42  https://www.ilmateenistus.ee/wp-content/upload...
# 43  https://www.ilmateenistus.ee/wp-content/upload...
# 44  https://www.ilmateenistus.ee/wp-content/upload...
# 45  https://www.ilmateenistus.ee/wp-content/upload...
# 46  https://www.ilmateenistus.ee/wp-content/upload...
# 47  https://www.ilmateenistus.ee/wp-content/upload...
# 48  https://www.ilmateenistus.ee/wp-content/upload...
# 49  https://www.ilmateenistus.ee/wp-content/upload...
# 50  https://www.ilmateenistus.ee/wp-content/upload...
# 51  https://www.ilmateenistus.ee/wp-content/upload...
# 52  https://www.ilmateenistus.ee/wp-content/upload...
# 53  https://www.ilmateenistus.ee/wp-content/upload...
# 54  https://www.ilmateenistus.ee/wp-content/upload...
# 55  https://www.ilmateenistus.ee/wp-content/upload...
# 56  https://www.ilmateenistus.ee/wp-content/upload...
# 57  https://www.ilmateenistus.ee/wp-content/upload...
#
#                                            parquet  \
# 0                     Aesoo-1929-2019.parquet.gzip
# 1                      Ahja-1960-2019.parquet.gzip
# 2                    Alajoe-1978-2019.parquet.gzip
# 3                  Arbavere-2007-2019.parquet.gzip
# 4                     Audru-2007-2019.parquet.gzip
# 5                     Audru-2007-2019.parquet.gzip
# 6            Elva-1981-1996_2009-2019.parquet.gzip
# 7            Elva-1981-1996_2009-2019.parquet.gzip
# 8                     Huuru_1968-2019.parquet.gzip
# 9         Kaansoo_1980-1966_2007-2019.parquet.gzip
# 10        Kaansoo_1980-1966_2007-2019.parquet.gzip
# 11                   Kasari_1925-2019.parquet.gzip
# 12                    Kehra_1982-2019.parquet.gzip
# 13                    Keila_1923-2019.parquet.gzip
# 14                 Kirumpaa-2015-2019.parquet.gzip
# 15  Kloostrimetsa-1973-1999_2007-2019.parquet.gzip
# 16  Kloostrimetsa-1973-1999_2007-2019.parquet.gzip
# 17       Konuvere-1947-1999_2007-2019.parquet.gzip
# 18       Konuvere-1947-1999_2007-2019.parquet.gzip
# 19         Korela-1962-1966_2007-2019.parquet.gzip
# 20         Korela-1962-1966_2007-2019.parquet.gzip
# 21                    Kaapa-1955-2019.parquet.gzip
# 22                    Laadi-2007-2019.parquet.gzip
# 23                   Luguse-1970-2019.parquet.gzip
# 24                 Luganuse-1923-2019.parquet.gzip
# 25             Narvakarjaar-2006-2019.parquet.gzip
# 26                Narvalinn_2003-2019.parquet.gzip
# 27                    Nurme-2007-2019.parquet.gzip
# 28                     Oore-1922-2019.parquet.gzip
# 29                  Pajupea-1928-2019.parquet.gzip
# 30                   Pajusi-1932-2019.parquet.gzip
# 31                  Pudisoo-1961-2019.parquet.gzip
# 32                 PohjakaI-1970-2019.parquet.gzip
# 33                PohjakaII-1976-2019.parquet.gzip
# 34             Rannu-Joesuu-1961-2019.parquet.gzip
# 35                    Reola-1986-2019.parquet.gzip
# 36                    Riisa-1925-2019.parquet.gzip
# 37                 Roostoja-1974-2019.parquet.gzip
# 38                   Rapina-1959-2019.parquet.gzip
# 39                   Separa-2011-2019.parquet.gzip
# 40                     Sami-1942-2019.parquet.gzip
# 41                   Taheva-2007-2019.parquet.gzip
# 42                  Tahkuse-1932-2019.parquet.gzip
# 43                    Tartu-1922-2019.parquet.gzip
# 44                 Tarvastu-2007-2019.parquet.gzip
# 45                Toila-Oru-2008-2019.parquet.gzip
# 46                     Tori-1956-2019.parquet.gzip
# 47                Tudulinna-1956-2019.parquet.gzip
# 48                 Tolliste-1922-2019.parquet.gzip
# 49                    Torva-1946-2019.parquet.gzip
# 50                    Torve-1925-2019.parquet.gzip
# 51     Tanassilma-1955-1969_2009-2019.parquet.gzip
# 52    Turi-Alliku-1971-1972_1977-2019.parquet.gzip
# 53                 Uue-Love-1934-2019.parquet.gzip
# 54                 Vanakula-1946-2019.parquet.gzip
# 55                  Varangu-2011-2019.parquet.gzip
# 56     Vihterpalu-1930-1944_1946-2019.parquet.gzip
# 57                    Vodja_1964-2019.parquet.gzip
#
#                                       csv       trend             p      h  \
# 0                     Aesoo-1929-2019.csv  decreasing  3.228669e-02   True
# 1                      Ahja-1960-2019.csv  decreasing  8.881784e-15   True
# 2                    Alajoe-1978-2019.csv  decreasing  2.059386e-04   True
# 3                  Arbavere-2007-2019.csv  decreasing  1.738166e-07   True
# 4                     Audru-2007-2019.csv  decreasing  0.000000e+00   True
# 5                     Audru-2007-2019.csv  decreasing  0.000000e+00   True
# 6            Elva-1981-1996_2009-2019.csv  decreasing  0.000000e+00   True
# 7            Elva-1981-1996_2009-2019.csv  decreasing  0.000000e+00   True
# 8                     Huuru_1968-2019.csv  increasing  1.962894e-09   True
# 9         Kaansoo_1980-1966_2007-2019.csv  decreasing  0.000000e+00   True
# 10        Kaansoo_1980-1966_2007-2019.csv  decreasing  0.000000e+00   True
# 11                   Kasari_1925-2019.csv    no trend  1.403994e-01  False
# 12                    Kehra_1982-2019.csv  increasing  3.282582e-03   True
# 13                    Keila_1923-2019.csv  increasing  1.589316e-02   True
# 14                 Kirumpaa-2015-2019.csv  decreasing  3.651357e-03   True
# 15  Kloostrimetsa-1973-1999_2007-2019.csv  decreasing  2.458034e-13   True
# 16  Kloostrimetsa-1973-1999_2007-2019.csv  decreasing  2.458034e-13   True
# 17       Konuvere-1947-1999_2007-2019.csv  decreasing  5.694067e-11   True
# 18       Konuvere-1947-1999_2007-2019.csv  decreasing  5.694067e-11   True
# 19         Korela-1962-1966_2007-2019.csv  decreasing  0.000000e+00   True
# 20         Korela-1962-1966_2007-2019.csv  decreasing  0.000000e+00   True
# 21                    Kaapa-1955-2019.csv    no trend  1.741640e-01  False
# 22                    Laadi-2007-2019.csv  decreasing  7.077450e-12   True
# 23                   Luguse-1970-2019.csv    no trend  1.611133e-01  False
# 24                 Luganuse-1923-2019.csv  decreasing  2.287217e-03   True
# 25             Narvakarjaar-2006-2019.csv  decreasing  3.497789e-02   True
# 26                Narvalinn_2003-2019.csv    no trend  2.623389e-01  False
# 27                    Nurme-2007-2019.csv  decreasing  2.258756e-08   True
# 28                     Oore-1922-2019.csv  increasing  9.075939e-03   True
# 29                  Pajupea-1928-2019.csv  increasing  1.454438e-03   True
# 30                   Pajusi-1932-2019.csv    no trend  4.429267e-01  False
# 31                  Pudisoo-1961-2019.csv  increasing  1.285177e-06   True
# 32                 PohjakaI-1970-2019.csv  decreasing  1.372271e-06   True
# 33                PohjakaII-1976-2019.csv  increasing  0.000000e+00   True
# 34             Rannu-Joesuu-1961-2019.csv    no trend  2.527135e-01  False
# 35                    Reola-1986-2019.csv  increasing  1.398981e-06   True
# 36                    Riisa-1925-2019.csv    no trend  9.840677e-02  False
# 37                 Roostoja-1974-2019.csv  increasing  3.900586e-02   True
# 38                   Rapina-1959-2019.csv  decreasing  1.085365e-07   True
# 39                   Separa-2011-2019.csv    no trend  2.074941e-01  False
# 40                     Sami-1942-2019.csv  decreasing  1.157115e-05   True
# 41                   Taheva-2007-2019.csv    no trend  5.990391e-01  False
# 42                  Tahkuse-1932-2019.csv    no trend  1.478177e-01  False
# 43                    Tartu-1922-2019.csv    no trend  8.489997e-02  False
# 44                 Tarvastu-2007-2019.csv  decreasing  0.000000e+00   True
# 45                Toila-Oru-2008-2019.csv  decreasing  0.000000e+00   True
# 46                     Tori-1956-2019.csv    no trend  2.699917e-01  False
# 47                Tudulinna-1956-2019.csv    no trend  4.759545e-01  False
# 48                 Tolliste-1922-2019.csv    no trend  8.380098e-01  False
# 49                    Torva-1946-2019.csv    no trend  8.766029e-01  False
# 50                    Torve-1925-2019.csv    no trend  1.664248e-01  False
# 51     Tanassilma-1955-1969_2009-2019.csv  decreasing  1.107036e-07   True
# 52    Turi-Alliku-1971-1972_1977-2019.csv  increasing  1.673874e-02   True
# 53                 Uue-Love-1934-2019.csv    no trend  8.776743e-01  False
# 54                 Vanakula-1946-2019.csv    no trend  1.889600e-01  False
# 55                  Varangu-2011-2019.csv    no trend  7.319953e-01  False
# 56     Vihterpalu-1930-1944_1946-2019.csv  increasing  9.615785e-04   True
# 57                    Vodja_1964-2019.csv  increasing  4.289217e-04   True
#
#        slope  years
# 0  -0.000045     20
# 1  -0.000084     20
# 2  -0.000016     20
# 3  -0.000067     13
# 4  -0.000167     20
# 5  -0.000167     20
# 6  -0.000133     20
# 7  -0.000133     20
# 8   0.000028     20
# 9  -0.000067     20
# 10 -0.000067     20
# 11  0.000076     20
# 12  0.000059     20
# 13  0.000038     20
# 14 -0.000245      5
# 15 -0.000255     20
# 16 -0.000255     20
# 17 -0.000155     20
# 18 -0.000155     20
# 19 -0.000141     20
# 20 -0.000141     20
# 21  0.000008     20
# 22 -0.000222     13
# 23 -0.000002     20
# 24 -0.000044     20
# 25 -0.000028     14
# 26  0.001076     17
# 27 -0.000121     13
# 28  0.000313     20
# 29  0.000006     20
# 30  0.000019     20
# 31  0.000015     20
# 32 -0.000012     20
# 33  0.000007     20
# 34 -0.000074     20
# 35  0.000019     20
# 36  0.000065     20
# 37  0.000015     20
# 38 -0.000092     20
# 39 -0.000024      9
# 40 -0.000051     20
# 41 -0.000033     13
# 42 -0.000070     20
# 43  0.000219     20
# 44 -0.000036     13
# 45 -0.000124     12
# 46  0.000007     20
# 47  0.000002     20
# 48  0.000003     20
# 49  0.000000     20
# 50 -0.000020     20
# 51 -0.000095     20
# 52  0.000031     20
# 53  0.000000     20
# 54  0.000013     20
# 55 -0.000009      9
# 56  0.000029     20
# 57  0.000004     20

# %%
for idx, row in collector_df.iterrows():
    test_df = pd.read_parquet(row['parquet'])
    
    test_df = test_df.loc[test_df['date2'] >= '1999-04']
    mind = test_df['date2'].min()
    maxd = test_df['date2'].max()
    years = int((maxd - mind).days / 365) 
    # test_df.dtypes
    print(f"{idx} {row['csv']} mind {mind} maxd {maxd} years {years}")
    # break

# %%
years.days / 365
# Out:
# 31.016438356164382

# %%
collector_df.to_parquet('calculated_flow_trends_estonia_last20years.parquet.gzip', index=False, compression='gzip')

# %%
collector_df.head()
# Out:
#                                                  url  \
# 0  https://www.ilmateenistus.ee/wp-content/upload...
# 1  https://www.ilmateenistus.ee/wp-content/upload...
# 2  https://www.ilmateenistus.ee/wp-content/upload...
# 3  https://www.ilmateenistus.ee/wp-content/upload...
# 4  https://www.ilmateenistus.ee/wp-content/upload...
#
#                            parquet                     csv       trend  \
# 0     Aesoo-1929-2019.parquet.gzip     Aesoo-1929-2019.csv  decreasing
# 1      Ahja-1960-2019.parquet.gzip      Ahja-1960-2019.csv  decreasing
# 2    Alajoe-1978-2019.parquet.gzip    Alajoe-1978-2019.csv  decreasing
# 3  Arbavere-2007-2019.parquet.gzip  Arbavere-2007-2019.csv  decreasing
# 4     Audru-2007-2019.parquet.gzip     Audru-2007-2019.csv  decreasing
#
#               p     h     slope  years
# 0  3.228669e-02  True -0.000045     20
# 1  8.881784e-15  True -0.000084     20
# 2  2.059386e-04  True -0.000016     20
# 3  1.738166e-07  True -0.000067     13
# 4  0.000000e+00  True -0.000167     20

# %%
collector_df['trend'].value_counts()
# Out:
# decreasing    27
# no trend      19
# increasing    12
# Name: trend, dtype: int64

# %%
import geopandas as gpd

stations = gpd.read_file(r'C:\dev\05_geodata\climate\stations\Estonia_ilmateenistus_3301.shp')

# %%
stations.head()
# Out:
#           stations wmocode           longitude            latitude  \
# 0  Kuressaare linn    None   22.48944444411111   58.26416666666667
# 1    Tallinn-Harku   26038  24.602891666624284  59.398122222355134
# 2            Pakri   26029  24.040080555476536   59.38950277719013
# 3            Kunda   26045  26.541397222079624   59.52141111042325
# 4            Jõhvi   26046   27.39827499992098   59.32902499979958
#
#         ascii_sani  ID  INLET  PTSOURCE  RES                        geometry
# 0  kuressaare linn   1      0         0    0  POINT (411346.597 6459155.342)
# 1    tallinn_harku   2      0         0    0  POINT (534250.544 6584618.823)
# 2            pakri   3      0         0    0  POINT (502277.599 6583505.345)
# 3            kunda   4      0         0    0  POINT (643825.046 6600924.969)
# 4            johvi   5      0         0    0  POINT (693367.350 6581666.569)

# %%
stations.sort_values(by='ascii_sani').head()
# Out:
#     stations wmocode           longitude            latitude ascii_sani  ID  \
# 80     Aesoo   41137  25.061666666666667  58.515277777777776      aesoo  81
# 65      Ahja   41061  27.112222222222222   58.20916666666667       ahja  66
# 50    Alajõe   41163  27.392499999666665   59.03083333266667     alajoe  51
# 71  Arbavere   41080   25.96333333333333   59.43999999966667   arbavere  72
# 90     Audru   41196  24.318413888211627  58.423316666148345      audru  91
#
#     INLET  PTSOURCE  RES                        geometry
# 80      0         0    0  POINT (561868.455 6486615.048)
# 65      0         0    0  POINT (682888.074 6456274.862)
# 50      0         0    0  POINT (694718.298 6548475.264)
# 71      0         0    0  POINT (611386.884 6590760.518)
# 90      0         0    0  POINT (518604.844 6475927.043)

# %%
def parse_station(csv_file):
    elems = csv_file.replace('.csv', '').replace('_', '-').split('-')
    length = len(elems)
    name_parts = []
    for num in range(length-2):
        part = elems[num]
        try:
            int(part)
        except ValueError as ex:
            if num <= 2:
                name_parts.append(part.lower())
    
    return '_'.join(name_parts)

collector_df['station_name'] = collector_df['csv'].apply(parse_station)

# %%
collector_df.sample(3)
# Out:
#                                                   url  \
# 40  https://www.ilmateenistus.ee/wp-content/upload...
# 1   https://www.ilmateenistus.ee/wp-content/upload...
# 49  https://www.ilmateenistus.ee/wp-content/upload...
#
#                          parquet                  csv       trend  \
# 40   Sami-1942-2019.parquet.gzip   Sami-1942-2019.csv  decreasing
# 1    Ahja-1960-2019.parquet.gzip   Ahja-1960-2019.csv  decreasing
# 49  Torva-1946-2019.parquet.gzip  Torva-1946-2019.csv    no trend
#
#                p      h     slope  years station_name
# 40  1.157115e-05   True -0.000051     20         sami
# 1   8.881784e-15   True -0.000084     20         ahja
# 49  8.766029e-01  False  0.000000     20        torva

# %%
joined = pd.merge(stations, collector_df, left_on='ascii_sani', right_on='station_name', how='inner')

# %%
len(joined)
# Out:
# 51

# %%
joined.sample()
# Out:
#    stations wmocode           longitude            latitude ascii_sani  ID  \
# 36    Aesoo   41137  25.061666666666667  58.515277777777776      aesoo  81
#
#     INLET  PTSOURCE  RES                        geometry  \
# 36      0         0    0  POINT (561868.455 6486615.048)
#
#                                                   url  \
# 36  https://www.ilmateenistus.ee/wp-content/upload...
#
#                          parquet                  csv       trend         p  \
# 36  Aesoo-1929-2019.parquet.gzip  Aesoo-1929-2019.csv  decreasing  0.032287
#
#        h     slope  years station_name
# 36  True -0.000045     20        aesoo

# %%
joined
# Out:
#          stations wmocode           longitude            latitude  \
# 0          Separa   41202  27.036666666333335   58.96611111111111
# 1        Uue-Lõve   41156  22.822222221555556  58.364444444444445
# 2          Luguse   41154   22.71333333333333   58.81055555555555
# 3     Türi-Alliku   41158   25.47277777711111   58.82999999933334
# 4           Hüüru   41103   24.53472222188889  59.379999999333336
# 5         Pajupea   41097   24.96888888822222   59.38083333266667
# 6           Kehra   41087   25.34027777744444   59.34416666633333
# 7         Pudisoo   41085   25.59444444411111   59.50861111111111
# 8          Alajõe   41163  27.392499999666665   59.03083333266667
# 9       Tudulinna   41066  27.088333332999998   59.03666666633333
# 10          Kääpa   41063  26.848888888555553   58.70055555555556
# 11       Roostoja   41065   27.10527777777778   59.02333333266667
# 12          Tõrva   41069  25.921111110444446   58.00361111111111
# 13          Reola   41184  26.741944444111112   58.27333333266667
# 14         Korela   41015  27.726111110444442   57.88527777744445
# 15         Korela   41015  27.726111110444442   57.88527777744445
# 16         Räpina   41019  27.454444444444444   58.09555555522222
# 17   Rannu-Jõesuu   41022  26.134166666333332  58.385555555222226
# 18          Tõrve   41028  26.374722221555555  58.602222222222224
# 19           Elva   41058   26.43444444411111   58.21138888888889
# 20           Elva   41058   26.43444444411111   58.21138888888889
# 21           Ahja   41061  27.112222222222222   58.20916666666667
# 22      Toila-Oru   41193   27.52999999933333   59.42305555488888
# 23       Tõlliste   41067  26.132499999333334  57.850833333333334
# 24     Tänassilma   41070  25.821944443777777   58.39472222188889
# 25       Lüganuse   41074  27.038888888555558   59.38361111077778
# 26           Sämi   41077   26.58277777711111   59.37277777711111
# 27       Arbavere   41080   25.96333333333333   59.43999999966667
# 28       Vanaküla   41082  25.789166666333333  59.467499999333334
# 29          Keila   41107   24.43472222188889  59.308611111111105
# 30     Vihterpalu   41110  23.866388888888892   59.25194444444445
# 31         Kasari   41112   23.99694444411111  58.726388888222225
# 32       Konuvere   41116   24.38972222188889  58.801111111111105
# 33       Konuvere   41116   24.38972222188889  58.801111111111105
# 34        Tahkuse   41126  24.915555555555553  58.518333332666664
# 35           Oore   41127   24.76749999933333  58.463055555555556
# 36          Aesoo   41137  25.061666666666667  58.515277777777776
# 37          Riisa   41140  24.994166666333335   58.47944444377778
# 38  Kloostrimetsa   41157   24.87961944407448   59.46631388876173
# 39  Kloostrimetsa   41157   24.87961944407448   59.46631388876173
# 40        Kaansoo   41174  25.221666665999997   58.57722222155556
# 41        Kaansoo   41174  25.221666665999997   58.57722222155556
# 42         Pajusi   41175  25.927777777111114   58.70305555555556
# 43       Kirumpää   41192  26.992499999666666   57.86555555555556
# 44        Varangu   41201  26.351666666666667  59.472222221555555
# 45         Taheva   41195  26.349166666333332        57.598333333
# 46          Laadi   41197        24.638333333   58.26749999933333
# 47          Audru   41196  24.318413888211627  58.423316666148345
# 48          Audru   41196  24.318413888211627  58.423316666148345
# 49          Nurme   41198  24.498263888555556  58.446274999709054
# 50       Tarvastu   41199   25.88444444411111   58.23027777711111
#
#        ascii_sani  ID  INLET  PTSOURCE  RES                        geometry  \
# 0          separa  43      0         0    0  POINT (674635.678 6540294.463)
# 1        uue_love  44      0         0    0  POINT (431070.888 6469930.957)
# 2          luguse  45      0         0    0  POINT (425651.999 6519727.103)
# 3     turi_alliku  46      0         0    0  POINT (585052.969 6522113.600)
# 4           huuru  47      0         0    0  POINT (530393.989 6582567.174)
# 5         pajupea  48      0         0    0  POINT (555069.656 6582936.592)
# 6           kehra  49      0         0    0  POINT (576257.831 6579216.003)
# 7         pudisoo  50      0         0    0  POINT (590281.226 6597847.073)
# 8          alajoe  51      0         0    0  POINT (694718.298 6548475.264)
# 9       tudulinna  52      0         0    0  POINT (677243.176 6548280.941)
# 10          kaapa  53      0         0    0  POINT (665099.366 6510268.387)
# 11       roostoja  54      0         0    0  POINT (678283.676 6546842.224)
# 12          torva  55      0         0    0  POINT (613573.751 6430763.582)
# 13          reola  57      0         0    0  POINT (660849.781 6462466.058)
# 14         korela  60      0         0    0  POINT (720931.736 6422095.258)
# 15         korela  60      0         0    0  POINT (720931.736 6422095.258)
# 16         rapina  61      0         0    0  POINT (703633.051 6444622.276)
# 17   rannu_joesuu  62      0         0    0  POINT (624812.050 6473662.824)
# 18          torve  64      0         0    0  POINT (638020.664 6498252.723)
# 19           elva  65      0         0    0  POINT (643069.771 6454875.335)
# 20           elva  65      0         0    0  POINT (643069.771 6454875.335)
# 21           ahja  66      0         0    0  POINT (682888.074 6456274.862)
# 22      toila_oru  67      0         0    0  POINT (700304.910 6592514.402)
# 23       tolliste  68      0         0    0  POINT (626607.683 6414133.684)
# 24     tanassilma  69      0         0    0  POINT (606529.566 6474144.940)
# 25       luganuse  70      0         0    0  POINT (672657.119 6586760.039)
# 26           sami  71      0         0    0  POINT (646803.167 6584468.094)
# 27       arbavere  72      0         0    0  POINT (611386.884 6590760.518)
# 28       vanakula  73      0         0    0  POINT (601426.538 6593546.699)
# 29          keila  74      0         0    0  POINT (524761.548 6574573.448)
# 30     vihterpalu  75      0         0    0  POINT (492376.959 6568188.202)
# 31         kasari  76      0         0    0  POINT (499823.002 6509639.219)
# 32       konuvere  77      0         0    0  POINT (522526.849 6518027.491)
# 33       konuvere  77      0         0    0  POINT (522526.849 6518027.491)
# 34        tahkuse  79      0         0    0  POINT (553349.780 6486829.850)
# 35           oore  80      0         0    0  POINT (544793.382 6480565.219)
# 36          aesoo  81      0         0    0  POINT (561868.455 6486615.048)
# 37          riisa  82      0         0    0  POINT (557994.352 6482564.113)
# 38  kloostrimetsa  83      0         0    0  POINT (549871.194 6592388.791)
# 39  kloostrimetsa  83      0         0    0  POINT (549871.194 6592388.791)
# 40        kaansoo  84      0         0    0  POINT (571065.816 6493671.968)
# 41        kaansoo  84      0         0    0  POINT (571065.816 6493671.968)
# 42         pajusi  85      0         0    0  POINT (611729.164 6508645.926)
# 43       kirumpaa  87      0         0    0  POINT (677564.213 6417722.189)
# 44        varangu  88      0         0    0  POINT (633284.306 6595056.671)
# 45         taheva  89      0         0    0  POINT (640451.019 6386457.127)
# 46          laadi  90      0         0    0  POINT (537462.385 6458706.592)
# 47          audru  91      0         0    0  POINT (518604.844 6475927.043)
# 48          audru  91      0         0    0  POINT (518604.844 6475927.043)
# 49          nurme  92      0         0    0  POINT (529094.283 6478548.013)
# 50       tarvastu  93      0         0    0  POINT (610697.492 6455937.670)
#
#                                                   url  \
# 0   https://www.ilmateenistus.ee/wp-content/upload...
# 1   https://www.ilmateenistus.ee/wp-content/upload...
# 2   https://www.ilmateenistus.ee/wp-content/upload...
# 3   https://www.ilmateenistus.ee/wp-content/upload...
# 4   https://www.ilmateenistus.ee/wp-content/upload...
# 5   https://www.ilmateenistus.ee/wp-content/upload...
# 6   https://www.ilmateenistus.ee/wp-content/upload...
# 7   https://www.ilmateenistus.ee/wp-content/upload...
# 8   https://www.ilmateenistus.ee/wp-content/upload...
# 9   https://www.ilmateenistus.ee/wp-content/upload...
# 10  https://www.ilmateenistus.ee/wp-content/upload...
# 11  https://www.ilmateenistus.ee/wp-content/upload...
# 12  https://www.ilmateenistus.ee/wp-content/upload...
# 13  https://www.ilmateenistus.ee/wp-content/upload...
# 14  https://www.ilmateenistus.ee/wp-content/upload...
# 15  https://www.ilmateenistus.ee/wp-content/upload...
# 16  https://www.ilmateenistus.ee/wp-content/upload...
# 17  https://www.ilmateenistus.ee/wp-content/upload...
# 18  https://www.ilmateenistus.ee/wp-content/upload...
# 19  https://www.ilmateenistus.ee/wp-content/upload...
# 20  https://www.ilmateenistus.ee/wp-content/upload...
# 21  https://www.ilmateenistus.ee/wp-content/upload...
# 22  https://www.ilmateenistus.ee/wp-content/upload...
# 23  https://www.ilmateenistus.ee/wp-content/upload...
# 24  https://www.ilmateenistus.ee/wp-content/upload...
# 25  https://www.ilmateenistus.ee/wp-content/upload...
# 26  https://www.ilmateenistus.ee/wp-content/upload...
# 27  https://www.ilmateenistus.ee/wp-content/upload...
# 28  https://www.ilmateenistus.ee/wp-content/upload...
# 29  https://www.ilmateenistus.ee/wp-content/upload...
# 30  https://www.ilmateenistus.ee/wp-content/upload...
# 31  https://www.ilmateenistus.ee/wp-content/upload...
# 32  https://www.ilmateenistus.ee/wp-content/upload...
# 33  https://www.ilmateenistus.ee/wp-content/upload...
# 34  https://www.ilmateenistus.ee/wp-content/upload...
# 35  https://www.ilmateenistus.ee/wp-content/upload...
# 36  https://www.ilmateenistus.ee/wp-content/upload...
# 37  https://www.ilmateenistus.ee/wp-content/upload...
# 38  https://www.ilmateenistus.ee/wp-content/upload...
# 39  https://www.ilmateenistus.ee/wp-content/upload...
# 40  https://www.ilmateenistus.ee/wp-content/upload...
# 41  https://www.ilmateenistus.ee/wp-content/upload...
# 42  https://www.ilmateenistus.ee/wp-content/upload...
# 43  https://www.ilmateenistus.ee/wp-content/upload...
# 44  https://www.ilmateenistus.ee/wp-content/upload...
# 45  https://www.ilmateenistus.ee/wp-content/upload...
# 46  https://www.ilmateenistus.ee/wp-content/upload...
# 47  https://www.ilmateenistus.ee/wp-content/upload...
# 48  https://www.ilmateenistus.ee/wp-content/upload...
# 49  https://www.ilmateenistus.ee/wp-content/upload...
# 50  https://www.ilmateenistus.ee/wp-content/upload...
#
#                                            parquet  \
# 0                    Separa-2011-2019.parquet.gzip
# 1                  Uue-Love-1934-2019.parquet.gzip
# 2                    Luguse-1970-2019.parquet.gzip
# 3     Turi-Alliku-1971-1972_1977-2019.parquet.gzip
# 4                     Huuru_1968-2019.parquet.gzip
# 5                   Pajupea-1928-2019.parquet.gzip
# 6                     Kehra_1982-2019.parquet.gzip
# 7                   Pudisoo-1961-2019.parquet.gzip
# 8                    Alajoe-1978-2019.parquet.gzip
# 9                 Tudulinna-1956-2019.parquet.gzip
# 10                    Kaapa-1955-2019.parquet.gzip
# 11                 Roostoja-1974-2019.parquet.gzip
# 12                    Torva-1946-2019.parquet.gzip
# 13                    Reola-1986-2019.parquet.gzip
# 14         Korela-1962-1966_2007-2019.parquet.gzip
# 15         Korela-1962-1966_2007-2019.parquet.gzip
# 16                   Rapina-1959-2019.parquet.gzip
# 17             Rannu-Joesuu-1961-2019.parquet.gzip
# 18                    Torve-1925-2019.parquet.gzip
# 19           Elva-1981-1996_2009-2019.parquet.gzip
# 20           Elva-1981-1996_2009-2019.parquet.gzip
# 21                     Ahja-1960-2019.parquet.gzip
# 22                Toila-Oru-2008-2019.parquet.gzip
# 23                 Tolliste-1922-2019.parquet.gzip
# 24     Tanassilma-1955-1969_2009-2019.parquet.gzip
# 25                 Luganuse-1923-2019.parquet.gzip
# 26                     Sami-1942-2019.parquet.gzip
# 27                 Arbavere-2007-2019.parquet.gzip
# 28                 Vanakula-1946-2019.parquet.gzip
# 29                    Keila_1923-2019.parquet.gzip
# 30     Vihterpalu-1930-1944_1946-2019.parquet.gzip
# 31                   Kasari_1925-2019.parquet.gzip
# 32       Konuvere-1947-1999_2007-2019.parquet.gzip
# 33       Konuvere-1947-1999_2007-2019.parquet.gzip
# 34                  Tahkuse-1932-2019.parquet.gzip
# 35                     Oore-1922-2019.parquet.gzip
# 36                    Aesoo-1929-2019.parquet.gzip
# 37                    Riisa-1925-2019.parquet.gzip
# 38  Kloostrimetsa-1973-1999_2007-2019.parquet.gzip
# 39  Kloostrimetsa-1973-1999_2007-2019.parquet.gzip
# 40        Kaansoo_1980-1966_2007-2019.parquet.gzip
# 41        Kaansoo_1980-1966_2007-2019.parquet.gzip
# 42                   Pajusi-1932-2019.parquet.gzip
# 43                 Kirumpaa-2015-2019.parquet.gzip
# 44                  Varangu-2011-2019.parquet.gzip
# 45                   Taheva-2007-2019.parquet.gzip
# 46                    Laadi-2007-2019.parquet.gzip
# 47                    Audru-2007-2019.parquet.gzip
# 48                    Audru-2007-2019.parquet.gzip
# 49                    Nurme-2007-2019.parquet.gzip
# 50                 Tarvastu-2007-2019.parquet.gzip
#
#                                       csv       trend             p      h  \
# 0                    Separa-2011-2019.csv    no trend  2.074941e-01  False
# 1                  Uue-Love-1934-2019.csv    no trend  8.776743e-01  False
# 2                    Luguse-1970-2019.csv    no trend  1.611133e-01  False
# 3     Turi-Alliku-1971-1972_1977-2019.csv  increasing  1.673874e-02   True
# 4                     Huuru_1968-2019.csv  increasing  1.962894e-09   True
# 5                   Pajupea-1928-2019.csv  increasing  1.454438e-03   True
# 6                     Kehra_1982-2019.csv  increasing  3.282582e-03   True
# 7                   Pudisoo-1961-2019.csv  increasing  1.285177e-06   True
# 8                    Alajoe-1978-2019.csv  decreasing  2.059386e-04   True
# 9                 Tudulinna-1956-2019.csv    no trend  4.759545e-01  False
# 10                    Kaapa-1955-2019.csv    no trend  1.741640e-01  False
# 11                 Roostoja-1974-2019.csv  increasing  3.900586e-02   True
# 12                    Torva-1946-2019.csv    no trend  8.766029e-01  False
# 13                    Reola-1986-2019.csv  increasing  1.398981e-06   True
# 14         Korela-1962-1966_2007-2019.csv  decreasing  0.000000e+00   True
# 15         Korela-1962-1966_2007-2019.csv  decreasing  0.000000e+00   True
# 16                   Rapina-1959-2019.csv  decreasing  1.085365e-07   True
# 17             Rannu-Joesuu-1961-2019.csv    no trend  2.527135e-01  False
# 18                    Torve-1925-2019.csv    no trend  1.664248e-01  False
# 19           Elva-1981-1996_2009-2019.csv  decreasing  0.000000e+00   True
# 20           Elva-1981-1996_2009-2019.csv  decreasing  0.000000e+00   True
# 21                     Ahja-1960-2019.csv  decreasing  8.881784e-15   True
# 22                Toila-Oru-2008-2019.csv  decreasing  0.000000e+00   True
# 23                 Tolliste-1922-2019.csv    no trend  8.380098e-01  False
# 24     Tanassilma-1955-1969_2009-2019.csv  decreasing  1.107036e-07   True
# 25                 Luganuse-1923-2019.csv  decreasing  2.287217e-03   True
# 26                     Sami-1942-2019.csv  decreasing  1.157115e-05   True
# 27                 Arbavere-2007-2019.csv  decreasing  1.738166e-07   True
# 28                 Vanakula-1946-2019.csv    no trend  1.889600e-01  False
# 29                    Keila_1923-2019.csv  increasing  1.589316e-02   True
# 30     Vihterpalu-1930-1944_1946-2019.csv  increasing  9.615785e-04   True
# 31                   Kasari_1925-2019.csv    no trend  1.403994e-01  False
# 32       Konuvere-1947-1999_2007-2019.csv  decreasing  5.694067e-11   True
# 33       Konuvere-1947-1999_2007-2019.csv  decreasing  5.694067e-11   True
# 34                  Tahkuse-1932-2019.csv    no trend  1.478177e-01  False
# 35                     Oore-1922-2019.csv  increasing  9.075939e-03   True
# 36                    Aesoo-1929-2019.csv  decreasing  3.228669e-02   True
# 37                    Riisa-1925-2019.csv    no trend  9.840677e-02  False
# 38  Kloostrimetsa-1973-1999_2007-2019.csv  decreasing  2.458034e-13   True
# 39  Kloostrimetsa-1973-1999_2007-2019.csv  decreasing  2.458034e-13   True
# 40        Kaansoo_1980-1966_2007-2019.csv  decreasing  0.000000e+00   True
# 41        Kaansoo_1980-1966_2007-2019.csv  decreasing  0.000000e+00   True
# 42                   Pajusi-1932-2019.csv    no trend  4.429267e-01  False
# 43                 Kirumpaa-2015-2019.csv  decreasing  3.651357e-03   True
# 44                  Varangu-2011-2019.csv    no trend  7.319953e-01  False
# 45                   Taheva-2007-2019.csv    no trend  5.990391e-01  False
# 46                    Laadi-2007-2019.csv  decreasing  7.077450e-12   True
# 47                    Audru-2007-2019.csv  decreasing  0.000000e+00   True
# 48                    Audru-2007-2019.csv  decreasing  0.000000e+00   True
# 49                    Nurme-2007-2019.csv  decreasing  2.258756e-08   True
# 50                 Tarvastu-2007-2019.csv  decreasing  0.000000e+00   True
#
#        slope  years   station_name
# 0  -0.000024      9         separa
# 1   0.000000     20       uue_love
# 2  -0.000002     20         luguse
# 3   0.000031     20    turi_alliku
# 4   0.000028     20          huuru
# 5   0.000006     20        pajupea
# 6   0.000059     20          kehra
# 7   0.000015     20        pudisoo
# 8  -0.000016     20         alajoe
# 9   0.000002     20      tudulinna
# 10  0.000008     20          kaapa
# 11  0.000015     20       roostoja
# 12  0.000000     20          torva
# 13  0.000019     20          reola
# 14 -0.000141     20         korela
# 15 -0.000141     20         korela
# 16 -0.000092     20         rapina
# 17 -0.000074     20   rannu_joesuu
# 18 -0.000020     20          torve
# 19 -0.000133     20           elva
# 20 -0.000133     20           elva
# 21 -0.000084     20           ahja
# 22 -0.000124     12      toila_oru
# 23  0.000003     20       tolliste
# 24 -0.000095     20     tanassilma
# 25 -0.000044     20       luganuse
# 26 -0.000051     20           sami
# 27 -0.000067     13       arbavere
# 28  0.000013     20       vanakula
# 29  0.000038     20          keila
# 30  0.000029     20     vihterpalu
# 31  0.000076     20         kasari
# 32 -0.000155     20       konuvere
# 33 -0.000155     20       konuvere
# 34 -0.000070     20        tahkuse
# 35  0.000313     20           oore
# 36 -0.000045     20          aesoo
# 37  0.000065     20          riisa
# 38 -0.000255     20  kloostrimetsa
# 39 -0.000255     20  kloostrimetsa
# 40 -0.000067     20        kaansoo
# 41 -0.000067     20        kaansoo
# 42  0.000019     20         pajusi
# 43 -0.000245      5       kirumpaa
# 44 -0.000009      9        varangu
# 45 -0.000033     13         taheva
# 46 -0.000222     13          laadi
# 47 -0.000167     20          audru
# 48 -0.000167     20          audru
# 49 -0.000121     13          nurme
# 50 -0.000036     13       tarvastu

# %%
type(joined)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
eesti = gpd.read_file('../data_archive/estonia_without_lakes.shp')

# %%
eest3301 = eesti.to_crs(3301)

# %%
def renumber(x):
    d = {
        'decreasing': -1,
        'no trend':    0,
        'increasing':  1
    }
    return d.get(x, 0)

joined['trend_num'] = joined['trend'].apply(renumber)

# %%
joined['slope_abs'] = joined['slope'].apply(abs)

# %%
from sklearn import preprocessing

normalized_arr = preprocessing.normalize([joined['slope_abs'].values])

joined['slope_norm'] = normalized_arr[0]

# %%
normalized_arr.min()
# Out:
# 0.0

# %%
# ( value - min ) / ( max - min ) * 20

minx = joined['slope_abs'].min()
maxx = joined['slope_abs'].max()
scale = 19

joined['slope_norm_man'] = 1 + ( joined['slope_abs'].values - minx ) / ( maxx - minx ) * scale

# %%
import mapclassify as mc

clf = mc.NaturalBreaks.make(k=20)

joined['slope_norm_class'] = 1 + joined[['slope_norm_man']].apply(clf)

# %%
joined[['slope_norm', 'slope_norm_man', 'slope_norm_class']].describe()
# Out:
#        slope_norm  slope_norm_man  slope_norm_class
# count   51.000000       51.000000         51.000000
# mean     0.100535        5.822295          8.058824
# std      0.098440        4.721814          5.668904
# min      0.000000        1.000000          1.000000
# 25%      0.024158        2.158775          3.000000
# 50%      0.074264        4.562155          7.000000
# 75%      0.162736        8.805834         12.500000
# max      0.396112       20.000000         20.000000

# %%
joined.sample(3)
# Out:
#     stations wmocode           longitude            latitude ascii_sani  ID  \
# 35      Oore   41127   24.76749999933333  58.463055555555556       oore  80
# 19      Elva   41058   26.43444444411111   58.21138888888889       elva  65
# 43  Kirumpää   41192  26.992499999666666   57.86555555555556   kirumpaa  87
#
#     INLET  PTSOURCE  RES                        geometry  ...         p     h  \
# 35      0         0    0  POINT (544793.382 6480565.219)  ...  0.009076  True
# 19      0         0    0  POINT (643069.771 6454875.335)  ...  0.000000  True
# 43      0         0    0  POINT (677564.213 6417722.189)  ...  0.003651  True
#
#        slope years  station_name  trend_num  slope_abs  slope_norm  \
# 35  0.000313    20          oore          1   0.000313    0.396112
# 19 -0.000133    20          elva         -1   0.000133    0.167977
# 43 -0.000245     5      kirumpaa         -1   0.000245    0.309792
#
#    slope_norm_man  slope_norm_class
# 35      20.000000                20
# 19       9.057197                13
# 43      15.859569                18
#
# [3 rows x 24 columns]

# %%
# Out:
# 'kiru..'

# %%
ax = eest3301.boundary.plot()

joined.plot(column='trend', categorical=True, legend=True, cmap='viridis', ax=ax)
# Out:
# <AxesSubplot:>

# %%
ax = landcatch.boundary.plot(color='darkgray', lw=0.9, figsize=(12,9))

clr = {
        'decreasing': 'darkred',
        'no trend':    'grey',
        'increasing':  'darkblue'
    }

for idx, row in joined.iterrows():
    tg = gpd.GeoDataFrame(pd.DataFrame(row).transpose(), geometry='geometry', crs=3301)
    msize = tg.iloc[0]['slope_norm_class'] * 5
    color = clr.get( tg.iloc[0]['trend'], 'grey' )
    tg.plot(ax=ax, color=color, markersize=msize, alpha=0.8 )
    stat_name = row['station_name'] if len(row['station_name']) < 6 else row['station_name'][0:4]+".."
    plt.text(tg['geometry'].x, row['geometry'].y,"{} ({}y)\n".format(stat_name, row['years']),size=8, color='black')

# %%
pd.DataFrame(row).transpose()
# Out:
#     stations wmocode          longitude           latitude ascii_sani  ID  \
# 50  Tarvastu   41199  25.88444444411111  58.23027777711111   tarvastu  93
#
#    INLET PTSOURCE RES                                     geometry  ...  \
# 50     0        0   0  POINT (610697.4923290922 6455937.669715327)  ...
#
#          trend  p     h       slope station_name trend_num   slope_abs  \
# 50  decreasing  0  True -3.5508e-05     tarvastu        -1  3.5508e-05
#
#    slope_norm slope_norm_man slope_norm_class
# 50  0.0643736        3.65436               10
#
# [1 rows x 23 columns]

# %%
import geoplot as gplt
import geoplot.crs as gcrs

# %%
ax = gplt.polyplot(eest3301.to_crs(4326), projection=gcrs.EuroPP(), figsize=(15,12))

gplt.pointplot(
    joined.to_crs(4326), projection=gcrs.EuroPP(),
    hue='trend_num', cmap='coolwarm_r', ax=ax,
    scale='slope_norm', limits=(5, 20),
)
# Out:
# <GeoAxesSubplot:>

# %%
catchments = gpd.read_file(r'C:\dev\05_geodata\hydrological\catchments\21_water\alamvesikonnad_uus.shp')

# %%
catchments.plot()
# Out:
# <AxesSubplot:>

# %%
catchments.crs = 'EPSG:3301'

# %%
landcatch = catchments.loc[catchments['MAA_MERI'] == 1]

# %%
import contextily as ctx

# %%
cat84 = landcatch.to_crs(4326)
stat84 = joined.to_crs(4326)

# %%
import matplotlib.pyplot as plt

ax = gplt.polyplot(cat84, projection=gcrs.EuroPP(), figsize=(15,12))

ax = gplt.pointplot(
    stat84, projection=gcrs.EuroPP(),
    hue='trend_num', cmap='coolwarm_r', ax=ax,
    scale='slope_norm_man', limits=(5, 20),
    legend=True,
    legend_var="hue"
)

plt.title("Increasing (blue) and decreasing (red) trends in measured river flows in Estonian catchments over the last decades")
# Out:
# Text(0.5, 1.0, 'Increasing (blue) and decreasing (red) trends in measured river flows in Estonian catchments over the last decades')

# %%
ax = landcatch.boundary.plot(color='black', lw=0.9, figsize=(12,9))

clr = {
        'decreasing': 'darkred',
        'no trend':    'grey',
        'increasing':  'darkblue'
    }

for idx, row in joined.iterrows():
    tg = gpd.GeoDataFrame(pd.DataFrame(row).transpose(), geometry='geometry', crs=3301)
    msize = tg.iloc[0]['slope_norm_class'] * 10
    color = clr.get( tg.iloc[0]['trend'], 'grey' )
    tg.plot(ax=ax, color=color, markersize=msize, alpha=0.8 )

# %%
for k, v in clr.items():
    print(v)
    
    # ,
           loc='lower left',
           ncol=2,
           mode='expand',
           fontsize=12
# Out:
# darkred
# grey
# darkblue

# %%
rivers = gpd.read_file('../data_archive/estonian_rivers.gpkg', layer='estonian_rivers_simpl', driver='GPKG')

# %%
import matplotlib.patches as mpatches
import collections

patchList = []

clr = {
        'increasing':  'darkblue',
        'no trend':    'grey',
        'decreasing': 'darkred'
    }

for k, v in clr.items():
    data_key = mpatches.Patch(color=v, label=k)
    patchList.append(data_key)

fig, ax = plt.subplots(figsize=(17,16))

rivers.plot(ax=ax, color='lightblue', lw=1, alpha=1.0)

for idx, row in joined.iterrows():
    tg = gpd.GeoDataFrame(pd.DataFrame(row).transpose(), geometry='geometry', crs=3301)
    msize = tg.iloc[0]['slope_norm_class'] * 10
    color = clr.get( tg.iloc[0]['trend'], 'grey' )
    tg.plot(ax=ax, color=color, markersize=msize, alpha=1.0 )
    stat_name = row['station_name'] if len(row['station_name']) < 6 else row['station_name'][0:4]+".."
    if not tg.iloc[0]['trend'] == 'no trend':
        if row['years'] < 20:
            plt.text(tg['geometry'].x, row['geometry'].y,"{} ({}y)\n".format(stat_name, row['years']),size=8, color='darkgrey')
        else:
            plt.text(tg['geometry'].x, row['geometry'].y,"{}\n".format(stat_name),size=8, color='black')
    
landcatch.boundary.plot(color='black', ax = ax)



plt.legend(handles=patchList)
plt.axis('off')
plt.title("Increasing (blue) and decreasing (red) trends in measured river flows in Estonian catchments over the last 20 years.\n(stations with less data indicated).")
plt.savefig('../source/_static/day-21-water.png')
plt.show()
